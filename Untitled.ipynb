# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind, wilcoxon

# %%
x=np.random.randn(100)
y=np.random.randn(100)

# %%
plt.plot(x)
plt.plot(y)

# %%
wilcoxon(x,y)
# Out:
# WilcoxonResult(statistic=2474.0, pvalue=0.8608010376424908)

# %%
x=np.random.randint(0,100,100)
y=np.random.randint(0,100,100)

# %%
plt.plot(x)
plt.plot(y)

# %%
wilcoxon(x,y)
# Out:
# WilcoxonResult(statistic=2142.5, pvalue=0.24580532472236616)

# %%
x=np.random.normal(0,1,100)
y=np.random.normal(0,1,100)

plt.plot(x)
plt.plot(y)

print(wilcoxon(x,y))
# Out:
# WilcoxonResult(statistic=2483.0, pvalue=0.8851770022716838)

# %%
x=np.random.normal(0,0.1,100)
y=np.random.normal(0,1,100)

plt.plot(x)
plt.plot(y)

print(wilcoxon(x,y))
# Out:
# WilcoxonResult(statistic=2368.0, pvalue=0.5893232417473824)
